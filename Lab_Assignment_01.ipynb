# %% [markdown]
# <a href="https://colab.research.google.com/github/snigdhashoily/-Data-Mining-Lab/blob/main/Lab_Assignment_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Mining Lab
#
# Course Code: CSE426
#
# Course Title: Data Mining Lab
#
# Submitted By
#
# Name: Sinigdha Akter Shoily
#
# ID: 212 505 1044
#
# Section: 8A
#
# Batch: 50th
#
# Semester: Spring 2024
#
# Department: CSE
#
# Supervised By
#
# Name: Mrinmoy Biswas Akash
#
# Lecturer
#
# Dept. of CSE (UITS)
#
# Date:04-03-2025

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
movie_df_raw = pd.read_csv("/content/drive/MyDrive/DM and W/ratings.csv")
movie_names = pd.read_csv("/content/drive/MyDrive/DM and W/movies.csv")

# %%
movie_df_raw
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
movie_names
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
# Load the ratings dataset
ratings = pd.read_csv('/content/drive/MyDrive/DM and W/ratings.csv')

# Create User-Movie Rating Matrix
user_movie_matrix = ratings.pivot(index='userId', columns='movieId', values='rating')

# Fill missing values with 0 (optional: you can use mean-centered values instead)
user_movie_matrix = user_movie_matrix.fillna(0)

# Compute Movie Similarity Matrix using Pearson Correlation
movie_similarity = user_movie_matrix.corr(method='pearson')

# Display the similarity matrix
print(movie_similarity)
# Out:
# movieId    1         2         3         4         5         6         7       \
# movieId
# 1        1.000000  0.231327  0.173213 -0.028917  0.192474  0.192686  0.143743
# 2        0.231327  1.000000  0.191945  0.071269  0.200526  0.158341  0.127569
# 3        0.173213  0.191945  1.000000  0.067143  0.370171  0.196442  0.351513
# 4       -0.028917  0.071269  0.067143  1.000000  0.167910  0.053755  0.258075
# 5        0.192474  0.200526  0.370171  0.167910  1.000000  0.215503  0.429890
# ...           ...       ...       ...       ...       ...       ...       ...
# 193581  -0.028906 -0.018291 -0.011729 -0.004138 -0.011456 -0.017712 -0.012033
# 193583  -0.028906 -0.018291 -0.011729 -0.004138 -0.011456 -0.017712 -0.012033
# 193585  -0.028906 -0.018291 -0.011729 -0.004138 -0.011456 -0.017712 -0.012033
# 193587  -0.028906 -0.018291 -0.011729 -0.004138 -0.011456 -0.017712 -0.012033
# 193609  -0.028906 -0.018291 -0.011729 -0.004138 -0.011456 -0.017712 -0.012033
#
# ...

# %%
# Load ratings and movies datasets
ratings = pd.read_csv("/content/drive/MyDrive/DM and W/ratings.csv")
movies = pd.read_csv("/content/drive/MyDrive/DM and W/movies.csv")

# Create User-Movie Rating Matrix
user_movie_matrix = ratings.pivot(index="userId", columns="movieId", values="rating")

# Fill missing values with 0 (or use mean imputation)
user_movie_matrix = user_movie_matrix.fillna(0)

# Compute Movie Similarity Matrix using Pearson Correlation
movie_similarity = user_movie_matrix.corr(method="pearson")

# %%
# Function to recommend similar movies
def recommend_movies(movie_id, top_n=5):
    if movie_id not in movie_similarity.index:
        return f"Movie ID {movie_id} not found in similarity matrix."

    # Get top N similar movies
    similar_movies = movie_similarity[movie_id].dropna().sort_values(ascending=False)[1:top_n+1]

    # Merge with movie titles
    recommended = movies[movies["movieId"].isin(similar_movies.index)][["movieId", "title"]].copy()

    # Add similarity scores
    recommended["similarity"] = recommended["movieId"].map(similar_movies)

    # Sort by similarity score
    recommended = recommended.sort_values(by="similarity", ascending=False).reset_index(drop=True)

    return recommended

    movie_id = 3
recommendations = recommend_movies(3, top_n=5)
print(recommendations)
# Out:
#    movieId                        title  similarity
# 0     3450        Grumpy Old Men (1993)    0.415447
# 1      762            Striptease (1996)    0.408148
# 2      788  Nutty Professor, The (1996)    0.388505
# 3      542            Son in Law (1993)    0.378602
# 4       65              Bio-Dome (1996)    0.371938

# %%
# Select a specific user
user_id = 47

# %%
#Q 01: Select a specific user from the dataset
user_ratings = ratings[ratings["userId"] == user_id]
print("User Ratings Data:\n", user_ratings)
# Out:
# User Ratings Data:
#        userId  movieId  rating   timestamp
# 6918      47       31     3.0  1496205717
# 6919      47       47     3.0  1496209354
# 6920      47       62     3.0  1496205312
# 6921      47      141     2.0  1496208714
# 6922      47      147     3.5  1496205843
# ...      ...      ...     ...         ...
# 7053      47   160980     3.5  1496209791
# 7054      47   161582     3.5  1496208845
# 7055      47   163645     3.0  1496205601
# 7056      47   166643     3.0  1496205070
# 7057      47   171011     3.0  1496206929
#
# [140 rows x 4 columns]

# %%
#Q 02: Identify the movie the user has rated the highest
if not user_ratings.empty:
    highest_rated_item = user_ratings.loc[user_ratings["rating"].idxmax()]
    print("\nHighest Rated Movie by User:\n", highest_rated_item)
else:
    print("\nUser has not rated any movies.")
# Out:
# Highest Rated Movie by User:
#  userId       4.700000e+01
# movieId      3.147000e+03
# rating       5.000000e+00
# timestamp    1.496205e+09
# Name: 6958, dtype: float64

# %%
#Q 03: Find movies that the user has NOT rated yet
all_movies = set(movies["movieId"])  # All available movies
rated_movies = set(user_ratings["movieId"])  # Movies rated by the user
unrated_movies = all_movies - rated_movies  # Movies the user has NOT rated

# Get details of unrated movies
unrated_movies_details = movies[movies["movieId"].isin(unrated_movies)]
print("\nUnrated Movies:\n", unrated_movies_details.head())
# Out:
# Unrated Movies:
#     movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
#Q 04: Recommend movies with the highest average rating
def recommend_movies_with_highest_avg_rating(user_id, top_n=5):

    # Get movies rated by the user
    user_ratings = ratings[ratings["userId"] == user_id]
    rated_movies = set(user_ratings["movieId"])  # Movies the user has rated
    all_movies = set(movies["movieId"])  # All available movies

    # Find movies the user has NOT rated
    unrated_movies = all_movies - rated_movies
    unrated_movies_details = movies[movies["movieId"].isin(unrated_movies)]

    # Compute average rating for each movie
    avg_ratings = ratings.groupby("movieId")["rating"].mean()

    # Merge unrated movies with their average ratings
    recommended_movies = unrated_movies_details.merge(
        avg_ratings, on="movieId", how="left"
    ).sort_values(by="rating", ascending=False).head(top_n)

    return recommended_movies[["movieId", "title", "rating"]]

# Get top 5 recommended movies
recommended_movies = recommend_movies_with_highest_avg_rating(user_id=47, top_n=5)
print("\nTop Recommended Movies:\n", recommended_movies)
# Out:
# Top Recommended Movies:
#        movieId                                 title  rating
# 46         53                       Lamerica (1994)     5.0
# 1203     1631                Assignment, The (1997)     5.0
# 8601   126921        The Fox and the Hound 2 (2006)     5.0
# 8650   128914  Tom Segura: Completely Normal (2014)     5.0
# 9571   187717      Won't You Be My Neighbor? (2018)     5.0
